# %% [markdown]
# #데이터 선별

# %% [markdown]
# ##정보 선별

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.1/shipping_selection.py

# %% [markdown]
# ##정보 선별 + 박스 루프

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.1/shipping_selection_loop.py

# %% [markdown]
# ##데이터 경고

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.1/warning.py

# %% [markdown]
# ##라벨지 출력

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.1/make_label.py
# Out:
# /content/drive/MyDrive/customer_database
# 11개의 메시지가 들어있습니다.
# 11개의 사진이 들어있습니다.
# 최종 2장의 페이지가 들어있습니다.

# %% [markdown]
# ---
#
# #*업데이트 될 내용*
#
# ---

# %% [markdown]
# ##SF Express 처리

# %% [markdown]
# ##KP 처리

# %% [markdown]
# ##DHL처리
