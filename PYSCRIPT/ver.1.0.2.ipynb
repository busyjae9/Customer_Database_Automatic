# %% [markdown]
# #드라이브 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #데이터 선별

# %% [markdown]
# ---
# ## 해당 달 시트에서 작동
# ---

# %% [markdown]
# ###정보 선별만

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.2/shipping_selection.py

# %% [markdown]
# ###정보 선별 + 루프

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.2/shipping_selection_loop.py
# Out:
# /content/drive/MyDrive/customer_database
# 이번 달은 :  202106   지난 달은 :  202105   지지난 달은 :  202104
#            Date  ... Warning
# 252  2021-05-14  ...
# 259  2021-05-14  ...
# 246  2021-05-14  ...     NaN
# 245  2021-05-14  ...     NaN
# 268  2021-05-15  ...
# ..          ...  ...     ...
# 446  2021-06-28  ...
# 458  2021-06-28  ...
# 450  2021-06-28  ...
# 447  2021-06-28  ...
# 448  2021-06-28  ...     NaN
#
# [373 rows x 21 columns]

# %% [markdown]
# ###데이터 경고

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.2/warning.py
# Out:
# /content/drive/MyDrive/customer_database
# 경고 실행

# %% [markdown]
# ---
# ## 이달 최종 시트에서 작동
# ---

# %% [markdown]
# ### Confirm 기반 아이템 선택

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.2/confirm_item.py
# Out:
# /content/drive/MyDrive/customer_database

# %% [markdown]
# ###최종 아이템 확인

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.2/check_ex.py
# Out:
# /content/drive/MyDrive/customer_database

# %% [markdown]
# ###라벨지 출력

# %% [markdown]
# - 라벨지를 출력하면 1_label 폴더에 저장됨
# - 고객데이터에 데이터 저장
# - 해당 월 시트에 저장
# - 선별데이터에서는 삭제
# - 재고데이터 해당 주차 시트에 재고 데이터 저장

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.2/make_label.py
# Out:
# /content/drive/MyDrive/customer_database
# 69개의 메시지가 들어있습니다.
# 69개의 사진이 들어있습니다.
# 최종 9장의 페이지가 들어있습니다.

# %% [markdown]
# ###라벨만 다시 뽑기

# %% [markdown]
# 라벨을 뽑고 수정을 하고 다시 뽑기

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.2/make_label_replay.py

# %% [markdown]
# ---
# ##배송처리
# ---

# %% [markdown]
# ###SF Express 처리

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.2/SF_Express.py

# %% [markdown]
# ###KP 처리

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.2/KP.py

# %% [markdown]
# ###DHL처리

# %%
import os
os.chdir('/content/drive/MyDrive/customer_database')
print(os.getcwd())

# %run ver.1.0.2/DHL.py

# %% [markdown]
# ---
#
# #*업데이트 될 내용*
#
# ---
